# %%
import cv2

# %%
img=cv2.imread(r'D:\vs_code_DL\files\41Wzm9M+CxL.jpg')
img

# %%
cv2.imshow('Baby_images',img)
cv2.waitKey(5000) # no of seconds 5
cv2.destroyAllWindows() #close the window
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 cv2.imshow('Baby_images',img)
#       2 cv2.waitKey(5000) # no of seconds 5
#       3 cv2.destroyAllWindows() #close the window
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
img2=cv2.imread(r'D:\vs_code_DL\files\download (1).jpg')

# %%
img2.shape
# Out:
# (183, 275, 3)

# %%
cv2.imshow('m3',img2)
cv2.waitKey(3000)
cv2.destroyAllWindows()

# %% [markdown]
# convert image into greyscale

# %%
img_gray=cv2.imread(r'D:\vs_code_DL\files\download (1).jpg',cv2.IMREAD_GRAYSCALE)
img_gray
# Out:
# array([[168, 185, 154, ..., 132, 122, 119],
#        [150, 148, 137, ..., 107, 101,  93],
#        [172, 158, 171, ...,  61,  78,  85],
#        ...,
#        [152, 151, 151, ..., 115, 115, 116],
#        [153, 149, 147, ..., 136, 136, 137],
#        [158, 153, 150, ..., 133, 133, 133]], shape=(183, 275), dtype=uint8)

# %%
img_gray.shape
# Out:
# (183, 275)

# %%
cv2.imshow('m3_grey',img_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
cv2.imwrite('m3_grayscale.jpg',img_gray)
# Out:
# True

# %%
img3=cv2.imread(r'D:\vs_code_DL\files\download.jpg')

# %%
img_grey2=cv2.imread(r'D:\vs_code_DL\files\download.jpg',cv2.IMREAD_GRAYSCALE)
cv2.imwrite('grey.jpg',img_grey2)
# Out:
# True

# %% [markdown]
# convert to binary

# %%
thres,bin_img=cv2.threshold(img_grey2,100,255,cv2.THRESH_BINARY)
cv2.imshow('binary_image',bin_img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
thres # ---->upto 100 balck and rest white
# Out:
# 100.0

# %%
thres2,bin_img2=cv2.threshold(img_gray,50,255,cv2.THRESH_BINARY)
cv2.imshow('binary',bin_img2)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
thres3,bin_img3=cv2.threshold(img_gray,100,255,cv2.THRESH_OTSU) # automatically assign thresh
cv2.imshow('binary',bin_img3)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %% [markdown]
# display using matplotlib

# %%
import matplotlib.pyplot as plt
img4=cv2.imread(r'D:\vs_code_DL\files\download (1).jpg')


plt.imshow(img4)

# %%
conv_img=cv2.cvtColor(img4,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img)
