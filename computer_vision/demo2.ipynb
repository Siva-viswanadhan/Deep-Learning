# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread(r'D:\vs_code_DL\files\download (2).jpg')
img.shape
# Out:
# (146, 263, 3)

# %%
plt.imshow(img)

# %%
conv_img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img1)

# %% [markdown]
# bounding box
#
#
# rectangle
#
# two coordinates needed
# left top and right bottom

# %%
cv2.rectangle(conv_img1,pt1=(20,25),pt2=(260,120),color=(255,0,0),thickness=1)
plt.imshow(conv_img1)

# %%
img2=cv2.imread(r'D:\vs_code_DL\files\b2ap3_large_ee72093c-3c01-433a-8d25-701cca06c975.jpg')

# %%
plt.imshow(img2)

# %%
conv_img_face=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img_face)

# %% [markdown]
# cv2.rectangle(conv_img1,pt1=(20,25),pt2=(260,120),color=(255,0,0),thickness=1)
# plt.imshow(conv_img1)

# %%
cv2.circle(conv_img_face,center=(690,410),radius=390,color=(255,0,0),thickness=3)
plt.imshow(conv_img_face)

# %%
cv2.circle(conv_img_face,center=(690,410),radius=390,color=(255,0,0),thickness=-5)
plt.imshow(conv_img_face)

# %%
img3=cv2.imread(r'D:\vs_code_DL\files\download (3).jpg')
plt.imshow(img3)

# %%
conv_img3=cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img3)

# %% [markdown]
# adding text

# %%
cv2.putText(conv_img3,text='yamaha R1',org=(30,25),fontFace=cv2.FONT_HERSHEY_COMPLEX,fontScale=1,color=[0,255,255],thickness=1)
plt.imshow(conv_img3)
