# %%
import cv2
import mediapipe as mp

# %%
mp_hands=mp.solutions.hands
mp_draw=mp.solutions.drawing_utils
hand=mp_hands.Hands(max_num_hands=1)

# %%
video=cv2.VideoCapture(0)
while True:
    suc,img=video.read()
    img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    result=hand.process(img1)
    # print(result.multi_hand_landmarks)

    tipid=[4,8,12,16,20] #---> initialize tip id
    lmlist=[]


    if result.multi_hand_landmarks:
        for handlms in result.multi_hand_landmarks:
            for id,lm in enumerate(handlms.landmark):
                # print(id,lm)
                cx=lm.x
                cy=lm.y
                lmlist.append([id,cx,cy])
                # print(lmlist)


                if len(lmlist)!=0 and len(lmlist)==21:
                    finger_count=[]
                    #thump count

                    if lmlist[12][1] < lmlist[20][1]:
                        if lmlist[4][1] > lmlist[3][1]:
                            finger_count.append(0)
                        else:
                            finger_count.append(1)
                    else:
                        if lmlist[4][1] < lmlist[3][1]: # 1 i sthe x coordinate
                            finger_count.append(0)
                        else:
                            finger_count.append(1)
                     
                     #all finger except thumb
                    for i in range(1, 5):
                        if lmlist[tipid[i]][2] > lmlist[tipid[i] - 2][2]:  #2 is taing the y cooordinate 
                            finger_count.append(0)
                        else:
                            finger_count.append(1)
                    finger_count1=finger_count.count(1)


                    # print(finger_count)
                    # print(finger_count.count(1))
                    cv2.putText(img,'count:'+str(finger_count1),(35,400),cv2.FONT_HERSHEY_COMPLEX,3,(0,0,255))
                    

            mp_draw.draw_landmarks(img,handlms,mp_hands.HAND_CONNECTIONS,mp_draw.DrawingSpec(color=(0,0,255),thickness=5,circle_radius=5),mp_draw.DrawingSpec(color=(0,255,),thickness=3))


    
    cv2.imshow('finger count',img)
    if cv2.waitKey(1) & 0XFF==ord('q'):
        break




video.release()
cv2.destroyAllWindows()

# %%
# lst1=['orange','apple','grape','mango']
# for i,j in enumerate(lst1):
#     print(i,j)
